# %%
from scipy.stats import *
from scipy.integrate import quad
import numpy as np
import matplotlib.pyplot as plt
import math
def pdf(x, k):
    return (k**6)*(x**2) / (2*math.e**(k**2*x))
def cdf(x_0, k):
    return quad(pdf, 0, x_0, (k))[0]
def ppf(p, k):
    return

# %%
def plot_pdf(x_0, k):
    m = np.linspace(0, x_0, 10000)
    n = []
    for i in m:
        n.append(pdf(i, k))
    plt.plot(m, n)
    plt.title('PDF')
    plt.show()
plot_pdf(50, 0.7)
